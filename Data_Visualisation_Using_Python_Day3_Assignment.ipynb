# %% [markdown]
# <a href="https://colab.research.google.com/github/chittoorking/Data-visualisation-using-python-by-UpGrade-assignments/blob/main/Data_Visualisation_Using_Python_Day3_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import randn,randint,uniform,sample
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
sns.set(style='darkgrid')

# %%
data=sns.load_dataset('fmri')
data.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
data.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
sns.relplot(x='timepoint',y='signal',data=data,kind='line',hue='subject',style='event')

# %%
 sns.lineplot(x='timepoint',y='signal',data=data,hue='region',style='event')

# %%
sns.boxplot(x='region',y='signal',data=data,hue='event')
